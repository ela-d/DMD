# %%
# %run DMD_functions.ipynb

# %%
#x = np.array([0.2,0.8]).reshape(-1,1)
x = np.array([1,1]).reshape(-1,1)
A = np.diag([1, 0.5])
m=2
X = np.empty((x.shape[0], m))
Y = np.empty((x.shape[0], m))
X[:,0] = x.reshape(-1)
for i in range(m):
    Y[:,i] = A@X[:,i]
    if(i<m-1):
        X[:,i+1] = Y[:,i]
X, Y
# Out:
# (array([[1. , 1. ],
#         [1. , 0.5]]),
#  array([[1.  , 1.  ],
#         [0.5 , 0.25]]))

# %%
X2 = np.array([X[0,:], X[1,:],X[0,:]**2+X[1,:]**2,np.sin(X[0,:]), np.cos(X[1,:])]) #x1, x2, sin(x1), cos(x2)
Y2 = np.array([Y[0,:], Y[1,:],Y[0,:]**2+Y[1,:]**2, np.sin(Y[0,:]), np.cos(Y[1,:])])
X2, Y2

Z2, L2, r2 = GEDMDQ_multiple_trajectories(X2, Y2, tol=1e-12) #isto za 1e-6
print(Z2, L2, r2, sep="\n")


print(L2)

K=np.linalg.pinv(X2.conj().T)@Y2.conj().T
print("K = X*^+ Y*", K, sep="\n") 
mu, vec = np.linalg.eig(K)
mu, vec

scatter1=plt.scatter(np.real(L2), np.imag(L2), s=40)
scatter1.set_label("sin, cos bazne fje")
scatter2=plt.scatter([1, 0.5], [0,0], c="r", s=100)
scatter2.set_label("pravi")
scatter3=plt.scatter(np.real(mu), np.imag(mu), c="y", label="eig(YX+)", s=10)

plt.legend()
plt.grid()
# Out:
# [[-0.52306471 -0.00269728]
#  [-0.1379506  -0.51956621]
#  [-0.46845825 -0.78069795]
#  [-0.44014378 -0.00226968]
#  [-0.54239585  0.34720202]]
# [1.00260925 0.32089647]
# [0.0812254  0.10901414]
# [1.00260925 0.32089647]
# K = X*^+ Y*
# [[ 0.29131915  0.00273226  0.25695345  0.24513661  0.30787073]
#  [ 0.00546452  0.13500286  0.1060336   0.00459824 -0.04352545]
#  [ 0.15385636  0.20387042  0.28752713  0.12946566  0.08864719]
#  [ 0.24513661  0.00229912  0.21621887  0.20627534  0.25906428]
#  [ 0.35022665 -0.08774827  0.24063711  0.29470556  0.40338125]]

# %%
X2 = np.array([X[0,:], X[1,:],np.sin(X[0,:]), np.cos(X[1,:])]) #x1, x2, sin(x1), cos(x2)
Y2 = np.array([Y[0,:], Y[1,:],np.sin(Y[0,:]), np.cos(Y[1,:])])
X2, Y2

Z2, L2, r2 = GEDMDQ_multiple_trajectories(X2, Y2, tol=1e-12) #isto za 1e-6
print(Z2, L2, r2, sep="\n")


print(L2)

K=np.linalg.pinv(X2.conj().T)@Y2.conj().T
print("K = X*^+ Y*", K, sep="\n") 
mu, vec = np.linalg.eig(K)
mu, vec

scatter2=plt.scatter([1, 0.5], [0,0], c="r", s=100)
scatter2.set_label("pravi")
scatter1=plt.scatter(np.real(L2), np.imag(L2), s=40)
scatter1.set_label("sin, cos bazne fje")
scatter3=plt.scatter(np.real(mu), np.imag(mu), c="y", label="eig(YX+)", s=10)

plt.legend()
plt.grid()
# Out:
# [[-0.57271512  0.07382961]
#  [-0.05133021 -0.78126148]
#  [-0.48192316  0.06212548]
#  [-0.66114497  0.616701  ]]
# [0.95682939 0.45077513]
# [0.0529378  0.08682001]
# [0.95682939 0.45077513]
# K = X*^+ Y*
# [[ 0.36732164  0.10344087  0.3090905   0.35166097]
#  [ 0.20688174  0.40189472  0.17408498  0.07252481]
#  [ 0.3090905   0.08704249  0.26009069  0.2959125 ]
#  [ 0.30669115 -0.14543584  0.2580717   0.37829746]]

# %%
X2 = np.array([X[0,:], X[1,:], np.cos(X[1,:])]) #x1, x2, cos(x2)
Y2 = np.array([Y[0,:], Y[1,:], np.cos(Y[1,:])])
X2, Y2

Z2, L2, r2 = GEDMDQ_multiple_trajectories(X2, Y2, tol=1e-12) #isto za 1e-6
print(Z2, L2, r2, sep="\n")


print(L2)

K=np.linalg.pinv(X2.conj().T)@Y2.conj().T
print("K = X*^+ Y*", K, sep="\n") 
mu, vec = np.linalg.eig(K)
mu, vec

scatter2=plt.scatter([1, 0.5], [0,0], c="r", s=100)
scatter2.set_label("pravi")
scatter1=plt.scatter(np.real(L2), np.imag(L2), s=40)
scatter1.set_label("sin, cos bazne fje")
scatter3=plt.scatter(np.real(mu), np.imag(mu), c="y", label="eig(YX+)", s=10)

plt.legend()
plt.grid()
# Out:
# [[-0.6507303   0.10259048]
#  [-0.04862031 -0.76240203]
#  [-0.75775071  0.63891967]]
# [0.94069863 0.45962506]
# [0.0543802  0.07812271]
# [0.94069863 0.45962506]
# K = X*^+ Y*
# [[ 0.49644143  0.13980209  0.47527577]
#  [ 0.27960418  0.42237398  0.14214675]
#  [ 0.4144983  -0.11507644  0.48150828]]

# %%
X2 = np.array([X[0,:], np.cos(X[1,:])]) #x1, cos(x2)
Y2 = np.array([Y[0,:], np.cos(Y[1,:])])
X2, Y2

Z2, L2, r2 = GEDMDQ_multiple_trajectories(X2, Y2, tol=1e-12) #isto za 1e-6
print(Z2, L2, r2, sep="\n")


print(L2)

K=np.linalg.pinv(X2.conj().T)@Y2.conj().T
print("K = X*^+ Y*", K, sep="\n") 
mu, vec = np.linalg.eig(K)
mu, vec

scatter2=plt.scatter([1, 0.5], [0,0], c="r", s=100)
scatter2.set_label("pravi")
scatter1=plt.scatter(np.real(L2), np.imag(L2), s=40)
scatter1.set_label("sin, cos bazne fje")
scatter3=plt.scatter(np.real(mu), np.imag(mu), c="y", label="eig(YX+)", s=10)

plt.legend()
plt.grid()
# Out:
# [[-7.06108224e-01 -3.41800825e-15]
#  [-7.08103930e-01  1.00000000e+00]]
# [1.        0.2707833]
# [2.28878340e-16 1.00074151e-16]
# [1.        0.2707833]
# K = X*^+ Y*
# [[1.00000000e+00 7.31277722e-01]
#  [4.44089210e-16 2.70783297e-01]]

# %%
X2 = np.array([X[0,:], X[1,:]]) #x1, x2, sin(x1), cos(x2)
Y2 = np.array([Y[0,:], Y[1,:]])
X2, Y2

Z2, L2, r2 = GEDMDQ_multiple_trajectories(X2, Y2, tol=1e-12) #isto za 1e-6
print(Z2, L2, r2, sep="\n")


print(L2)

K=np.linalg.pinv(X2.conj().T)@Y2.conj().T
print("K = X*^+ Y*", K, sep="\n") 
mu, vec = np.linalg.eig(K)
mu, vec

scatter2=plt.scatter([1, 0.5], [0,0], c="r", s=100)
scatter2.set_label("pravi")
scatter1=plt.scatter(np.real(L2), np.imag(L2), s=40)
scatter1.set_label("sin, cos bazne fje")
scatter3=plt.scatter(np.real(mu), np.imag(mu), c="y", label="eig(YX+)", s=10)

plt.legend()
plt.grid()
# Out:
# [[-1.00000000e+00  1.34638103e-16]
#  [ 2.11898069e-16  1.00000000e+00]]
# [1.  0.5]
# [2.22044605e-16 1.11022302e-16]
# [1.  0.5]
# K = X*^+ Y*
# [[1.0000000e+00 0.0000000e+00]
#  [4.4408921e-16 5.0000000e-01]]

# %%
X2 = np.array([X[0,:], X[1,:],X[0,:]**2+X[1,:]**2]) #x1, x2, x1^2+x2^2
Y2 = np.array([Y[0,:], Y[1,:],Y[0,:]**2+Y[1,:]**2])
X2, Y2

Z2, L2, r2 = GEDMDQ_multiple_trajectories(X2, Y2, tol=1e-12) #isto za 1e-6
print(Z2, L2, r2, sep="\n")


print(L2)

K=np.linalg.pinv(X2.conj().T)@Y2.conj().T
print("K = X*^+ Y*", K, sep="\n") 
mu, vec = np.linalg.eig(K)
mu, vec

scatter2=plt.scatter([1, 0.5], [0,0], c="r", s=100)
scatter2.set_label("pravi")
scatter1=plt.scatter(np.real(L2), np.imag(L2), s=40)
scatter1.set_label("sin, cos bazne fje")
scatter3=plt.scatter(np.real(mu), np.imag(mu), c="y", label="eig(YX+)", s=10)

plt.legend()
plt.grid()
# Out:
# [[-0.7529817  -0.04155808]
#  [-0.17238062 -0.54459378]
#  [-0.63506179 -0.83766971]]
# [1.04130728 0.35154986]
# [0.11637912 0.10083146]
# [1.04130728 0.35154986]
# K = X*^+ Y*
# [[ 0.92857143 -0.10714286  0.73214286]
#  [-0.21428571  0.17857143 -0.05357143]
#  [ 0.14285714  0.21428571  0.28571429]]

# %% [markdown]
# ### NOVO
#
# bez kvadrata - ocekujem dobru procjenu

# %%
X2 = np.array([X[0,:], X[1,:],X[0,:]+X[1,:]]) #x1, x2, sin(x1), cos(x2)
Y2 = np.array([Y[0,:], Y[1,:],Y[0,:]+Y[1,:]])
X2, Y2

Z2, L2, r2 = GEDMDQ_multiple_trajectories(X2, Y2, tol=1e-12) #isto za 1e-6
print(Z2, L2, r2, sep="\n")


print(L2)

K=np.linalg.pinv(X2.conj().T)@Y2.conj().T
print("K = X*^+ Y*", K, sep="\n") 
mu, vec = np.linalg.eig(K)
mu, vec

scatter2=plt.scatter([1, 0.5], [0,0], c="r", s=100)
scatter2.set_label("pravi")
scatter1=plt.scatter(np.real(L2), np.imag(L2), s=40)
scatter1.set_label("sin, cos bazne fje")
scatter3=plt.scatter(np.real(mu), np.imag(mu), c="y", label="eig(YX+)", s=10)

plt.legend()
plt.grid()
# Out:
# [[-7.07106781e-01 -1.06260199e-15]
#  [ 3.92523115e-16 -7.07106781e-01]
#  [-7.07106781e-01 -7.07106781e-01]]
# [1.  0.5]
# [2.83732042e-16 2.11380166e-16]
# [1.  0.5]
# K = X*^+ Y*
# [[ 6.66666667e-01 -1.66666667e-01  5.00000000e-01]
#  [-3.33333333e-01  3.33333333e-01  4.44089210e-16]
#  [ 3.33333333e-01  1.66666667e-01  5.00000000e-01]]

# %% [markdown]
# SVe kvadrati ocekujem dobru procjenu za 0.25 i 1

# %%
X2 = np.array([X[0,:]**2, X[1,:]**2,X[0,:]**2+X[1,:]**2]) #x1, x2, sin(x1), cos(x2)
Y2 = np.array([Y[0,:]**2, Y[1,:]**2,Y[0,:]**2+Y[1,:]**2])
X2, Y2

Z2, L2, r2 = GEDMDQ_multiple_trajectories(X2, Y2, tol=1e-12) #isto za 1e-6
print(Z2, L2, r2, sep="\n")


print(L2)

K=np.linalg.pinv(X2.conj().T)@Y2.conj().T
print("K = X*^+ Y*", K, sep="\n") 
mu, vec = np.linalg.eig(K)
mu, vec

scatter2=plt.scatter([1, 0.25], [0,0], c="r", s=100)
scatter2.set_label("pravi")
scatter1=plt.scatter(np.real(L2), np.imag(L2), s=40)
scatter1.set_label("sin, cos bazne fje")
scatter3=plt.scatter(np.real(mu), np.imag(mu), c="y", label="eig(YX+)", s=10)

plt.legend()
plt.grid()
# Out:
# [[-7.07106781e-01  9.84097363e-16]
#  [-4.34565002e-16 -7.07106781e-01]
#  [-7.07106781e-01 -7.07106781e-01]]
# [1.   0.25]
# [1.97673920e-16 1.93405893e-16]
# [1.   0.25]
# K = X*^+ Y*
# [[ 0.66666667 -0.08333333  0.58333333]
#  [-0.33333333  0.16666667 -0.16666667]
#  [ 0.33333333  0.08333333  0.41666667]]

# %% [markdown]
# ako umjesto $x_1^2+x_2^2$ stavim $x_1^3+x_2^3$

# %%
X2 = np.array([X[0,:], X[1,:],X[0,:]**3+X[1,:]**3]) #x1, x2, sin(x1), cos(x2)
Y2 = np.array([Y[0,:], Y[1,:],Y[0,:]**3+Y[1,:]**3])
X2, Y2

Z2, L2, r2 = GEDMDQ_multiple_trajectories(X2, Y2, tol=1e-12) #isto za 1e-6
print(Z2, L2, r2, sep="\n")


print(L2)


scatter2=plt.scatter([1, 0.5, 0.25, 0.125], [0,0, 0, 0], c="r", s=100)
scatter2.set_label("pravi")
scatter1=plt.scatter(np.real(L2), np.imag(L2), s=40)
scatter1.set_label("sin, cos bazne fje")

plt.legend()
plt.grid()
# Out:
# [[-0.73482398 -0.02439328]
#  [-0.25432309 -0.49336207]
#  [-0.6287714  -0.86948194]]
# [1.02600736 0.23535628]
# [0.15525712 0.15153093]
# [1.02600736 0.23535628]

# %%
np.linalg.pinv(X2)
# Out:
# array([[-1.1969697 ,  0.62121212,  0.78787879],
#        [ 2.18181818, -0.72727273, -0.72727273]])

# %%
X2 = np.array([X[0,:]**2, X[1,:]**2]) #x1, x2, sin(x1), cos(x2)
Y2 = np.array([Y[0,:]**2, Y[1,:]**2])
X2, Y2

Z2, L2, r2 = GEDMDQ_multiple_trajectories(X2, Y2, tol=1e-12) #isto za 1e-6
print(Z2, L2, r2, sep="\n")


print(L2)

K=np.linalg.pinv(X2.conj().T)@Y2.conj().T
print("K = X*^+ Y*", K, sep="\n") 
mu, vec = np.linalg.eig(K)
mu, vec

scatter2=plt.scatter([1, 0.5], [0,0], c="r", s=100)
scatter2.set_label("pravi")
scatter1=plt.scatter(np.real(L2), np.imag(L2), s=40)
scatter1.set_label("sin, cos bazne fje")
scatter3=plt.scatter(np.real(mu), np.imag(mu), c="y", label="eig(YX+)", s=10)

plt.legend()
plt.grid()
# Out:
# [[-1.00000000e+00  3.24165028e-16]
#  [ 6.83580866e-17  1.00000000e+00]]
# [1.   0.25]
# [1.11022302e-16 3.92523115e-17]
# [1.   0.25]
# K = X*^+ Y*
# [[ 1.00000000e+00  4.16333634e-17]
#  [-2.22044605e-16  2.50000000e-01]]

# %%
###ISTA STVAR AKO ZAMIJENIM POREDAK U X... 

X3 = np.array([np.sin(X[0,:]), np.cos(X[1,:]),X[0,:], X[1,:],X[0,:]**2+X[1,:]**2]) #x1, x2, sin(x1), cos(x2)
Y3 = np.array([np.sin(Y[0,:]), np.cos(Y[1,:]),Y[0,:], Y[1,:],Y[0,:]**2+Y[1,:]**2])
X3, Y3

Z3, L3, r3 = GEDMDQ_multiple_trajectories(X2, Y2, tol=1e-12) #isto za 1e-6

print(L3)

K=np.linalg.pinv(X3.conj().T)@Y3.conj().T
print("K = X*^+ Y*", K, sep="\n") 
mu, vec = np.linalg.eig(K)
mu, vec

scatter1=plt.scatter(np.real(L3), np.imag(L2), s=40)
scatter1.set_label("sin, cos bazne fje")
scatter2=plt.scatter([1, 0.5], [0,0], c="r", s=100)
scatter2.set_label("pravi")
scatter3=plt.scatter(np.real(mu), np.imag(mu), c="y", label="eig(YX+)", s=10)

plt.legend()
plt.grid()
# Out:
# [1.   0.25]
# K = X*^+ Y*
# [[ 0.20627534  0.25906428  0.24513661  0.00229912  0.21621887]
#  [ 0.29470556  0.40338125  0.35022665 -0.08774827  0.24063711]
#  [ 0.24513661  0.30787073  0.29131915  0.00273226  0.25695345]
#  [ 0.00459824 -0.04352545  0.00546452  0.13500286  0.1060336 ]
#  [ 0.12946566  0.08864719  0.15385636  0.20387042  0.28752713]]

# %%
x = np.array([0.2,0.8]).reshape(-1,1)
A = np.diag([0.8, 0.6])
m=2
X = np.empty((x.shape[0], m))
Y = np.empty((x.shape[0], m))
X[:,0] = x.reshape(-1)
for i in range(m):
    Y[:,i] = A@X[:,i]
    if(i<m-1):
        X[:,i+1] = Y[:,i]
X, Y


X2 = np.array([X[0,:], X[1,:],X[0,:]**2+X[1,:]**2,np.sin(X[0,:]), np.cos(X[1,:])]) #x1, x2, sin(x1), cos(x2)
Y2 = np.array([Y[0,:], Y[1,:],Y[0,:]**2+Y[1,:]**2, np.sin(Y[0,:]), np.cos(Y[1,:])])
X2, Y2

Z2, L2, r2 = GEDMDQ_multiple_trajectories(X2, Y2, tol=1e-12) #isto za 1e-6
print(Z2, L2, r2, sep="\n")


print(L2)

K=np.linalg.pinv(X2.conj().T)@Y2.conj().T
print("K = X*^+ Y*", K, sep="\n") 
mu, vec = np.linalg.eig(K)
mu, vec

scatter1=plt.scatter(np.real(L2), np.imag(L2), s=40)
scatter1.set_label("sin, cos bazne fje")
scatter2=plt.scatter([0.8, 0.6], [0,0], c="r", s=100)
scatter2.set_label("pravi")
scatter3=plt.scatter(np.real(mu), np.imag(mu), c="y", label="eig(YX+)", s=10)

plt.legend()
plt.grid()
# Out:
# [[-0.11502729 -0.05549025]
#  [-0.18688962 -0.52382874]
#  [ 0.10070239 -0.73202877]
#  [-0.11491555 -0.05439895]
#  [-0.96358416  0.42860113]]
# [0.94705845 0.46319455]
# [0.09601801 0.10608589]
# [0.94705845 0.46319455]
# K = X*^+ Y*
# [[ 0.01967422  0.05390796  0.02585941  0.01960084  0.12234618]
#  [ 0.07187728  0.26766425  0.17216992  0.07146466  0.26339024]
#  [ 0.05461708  0.2769454   0.21164012  0.05415321  0.00918695]
#  [ 0.01955963  0.05342482  0.02552294  0.01948702  0.12207278]
#  [ 0.08258542  0.08059383 -0.05151913  0.08257514  0.89178739]]

# %% [markdown]
# HODMD

# %%
#x = np.array([0.2,0.8]).reshape(-1,1)
x = np.array([1,1, 1]).reshape(-1,1)
A = np.diag([1, 0.5, -0.7])
m=2
X = np.empty((x.shape[0], m))
Y = np.empty((x.shape[0], m))
X[:,0] = x.reshape(-1)
for i in range(m):
    Y[:,i] = A@X[:,i]
    if(i<m-1):
        X[:,i+1] = Y[:,i]
X, Y

Xs = np.vstack((X[:,:-1], X[:,1:]))
Ys = np.vstack((Y[:,:-1], Y[:,1:]))

Xs,Ys

Z, L, r = GEDMDQ_multiple_trajectories(X, Y, tol=1e-12) #isto za 1e-6
#print(Z, L, r, sep="\n")

Zs, Ls, rs = GEDMDQ_multiple_trajectories(Xs, Ys, tol=1e-12) #isto za 1e-6
#print(Z, L, r, sep="\n")

scatter2=plt.scatter([1, 0.5, -0.7], [0,0,0], c="r", s=100)
scatter2.set_label("pravi")
scatter1=plt.scatter(np.real(L), np.imag(L), s=40)
scatter1.set_label("bez stackanja")
scatter3=plt.scatter(np.real(Ls), np.imag(Ls), s=20)
scatter3.set_label("sa stackanjem")



plt.legend()
plt.grid()
